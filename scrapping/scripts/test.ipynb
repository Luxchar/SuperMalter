# %%
import pandas as pd

df = pd.DataFrame()

# add columns

df['col1'] = [1, 2, 3]

#append a row to the dataframe
df.loc[len(df)] = [4]

# %%
df
# Out:
#    col1
# 0     1
# 1     2
# 2     3
# 3     4
