# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../../data/raw_malt_data.csv')
df
# Out:
#                         name  \
# 0                        NaN
# 1          Alexandre Labayle
# 2                        NaN
# 3             José Thermique
# 4              Jérémy Herman
# ...                      ...
# 138799                   NaN
# 138800                   NaN
# 138801  Leslie Durand-Magona
# 138802    Mathis Charraudeau
# 138803                   NaN
#
#                                             profile_image  \
# 0                                        No profile image
# 1                                        No profile image
# 2                                                     NaN
# 3       https://dam.malt.com/p6afuz3bhpd4xrvbbcpu?grav...
# 4                                        No profile image
# ...                                                   ...
# 138799                                   No profile image
# 138800                                                NaN
# 138801  https://dam.malt.com/d86daa4a-5480-4d46-9dbf-2...
# 138802  https://dam.malt.com/e4bc2e92-5a72-4e70-89c5-8...
# 138803                                   No profile image
#
#                                      headline experience  price response_rate  \
# 0                                         NaN        NaN    NaN           NaN
# 1               Consultant décisionnel Senior          -  700 €          100%
# 2                                         NaN        NaN    NaN           NaN
# 3                Aménagement de salle de bain          -  400 €           NaN
# 4                        Photographe/Vidéaste          -  125 €          100%
# ...                                       ...        ...    ...           ...
# 138799                                    NaN        NaN    NaN           NaN
# 138800                                    NaN        NaN    NaN           NaN
# 138801                  Rédactrice, interview    0-2 ans  200 €          100%
# 138802  Expert Mac  - Consultant - Formateur   8-15 ans  500 €          100%
# 138803                                    NaN        NaN    NaN           NaN
#
#        response_time                                         categories  \
# 0                NaN                                                 []
# 1                 1h                                                 []
# 2                NaN                                                NaN
# 3                 1h                                                 []
# 4                 1h                                    ['Photographe']
# ...              ...                                                ...
# 138799           NaN                                                 []
# 138800           NaN                                                NaN
# 138801            1h                       ['Pigiste', 'Rédacteur web']
# 138802            1h  ['Chargé de formation', 'Administrateur Systèm...
# 138803           NaN                                                 []
#
#                                               competences supermalter  \
# 0                                                      []         NaN
# 1       ['Business object', 'SQL Server', 'Microsoft B...         NaN
# 2                                                     NaN         NaN
# 3       ['depannage', 'douche', 'bains', 'chauffage', ...         NaN
# 4       ['Photographie', 'Réalisation vidéo', 'paris',...         NaN
# ...                                                   ...         ...
# 138799                                                 []         NaN
# 138800                                                NaN         NaN
# 138801  ['Rédaction web', 'Blog', 'Réseaux sociaux', '...         NaN
# 138802  ['Formation', 'Mac OS', 'Matériel informatique...         NaN
# 138803                                                 []         NaN
#
#                                        location  \
# 0                                           NaN
# 1                          {'Localisation': ''}
# 2                                           NaN
# 3                          {'Localisation': ''}
# 4                          {'Localisation': ''}
# ...                                         ...
# 138799                                      NaN
# 138800                                      NaN
# 138801  {'Localisation': 'Saint-Denis, France'}
# 138802     {'Localisation': 'Toulouse, France'}
# 138803                                      NaN
#
#                                              presentation  recommendations  \
# 0                                                     NaN              NaN
# 1       Consultant Senior en Business Intelligence , 1...              NaN
# 2                                                     NaN              NaN
# 3       Bonjour je suis plombier-chauffagiste, spécial...              NaN
# 4                                                 Bonjour              NaN
# ...                                                   ...              ...
# 138799                                                NaN              NaN
# 138800                                                NaN              NaN
# 138801  Bonjour,Je suis à votre service pour toute ret...              NaN
# 138802  Passioné par le Mac et l'image numérique depui...              NaN
# 138803                                                NaN              NaN
#
#         missions  teletravail_preference              profil  \
# 0            NaN                     NaN         bricetillet
# 1            NaN                     NaN    alexandrelabayle
# 2            NaN                     NaN    siobhanengelmann
# 3            NaN                     NaN       josethermique
# 4            NaN                     NaN        jeremyherman
# ...          ...                     ...                 ...
# 138799       NaN                     NaN       gali203moutou
# 138800       NaN                     NaN             room309
# 138801       NaN                     NaN  lesliedurandmagona
# 138802       NaN                     NaN              mathis
# 138803       NaN                     NaN         eveguillard
#
#                                                   link creation_date
# 0              https://www.malt.fr/profile/bricetillet    2014-01-08
# 1         https://www.malt.fr/profile/alexandrelabayle    2014-02-04
# 2         https://www.malt.fr/profile/siobhanengelmann    2014-02-11
# 3            https://www.malt.fr/profile/josethermique    2014-02-19
# 4             https://www.malt.fr/profile/jeremyherman    2014-03-04
# ...                                                ...           ...
# 138799       https://www.malt.fr/profile/gali203moutou    2023-10-29
# 138800             https://www.malt.fr/profile/room309    2023-10-28
# 138801  https://www.malt.fr/profile/lesliedurandmagona    2023-10-17
# 138802              https://www.malt.fr/profile/mathis    2023-10-24
# 138803         https://www.malt.fr/profile/eveguillard    2023-11-04
#
# [138804 rows x 18 columns]

# %%
# separate the data into two dataframes

# if the name is NaN, then the data is not scrapped
df_data_scrapped = df[df['name'].notna()]
df_profile_links_not_scrapped = df[df['name'].isna()]

# concat the two dataframes
df_data_scrapped_2 = pd.read_csv('../../datasets/malt_data_scrapped.csv')
df_data_scrapped = pd.concat([df_data_scrapped, df_data_scrapped_2], ignore_index=True)

df_data_scrapped.to_csv('../../datasets/malt_data_scrapped.csv', index=False)
df_data_scrapped
# Out:
# /tmp/ipykernel_36517/3239141373.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_data_scrapped_2 = pd.read_csv('../../datasets/malt_data_scrapped.csv')
#                            name  \
# 0             Alexandre Labayle
# 1                José Thermique
# 2                 Jérémy Herman
# 3                  vince huguet
# 4               Patrick Bernard
# ...                         ...
# 245850              Lydia Ronné
# 245851               Ophélie D.
# 245852             Tony Marando
# 245853           Matthieu Sager
# 245854  Divine Manuella Monongi
#
#                                             profile_image  \
# 0                                        No profile image
# 1       https://dam.malt.com/p6afuz3bhpd4xrvbbcpu?grav...
# 2                                        No profile image
# 3                                        No profile image
# 4       https://dam.malt.com/f7d1sqcjznocacdi83ng?grav...
# ...                                                   ...
# 245850  https://dam.malt.com/0ab661d5-23a2-4a9a-a3a7-2...
# 245851  https://dam.malt.com/520ca9da-4784-44c5-9833-7...
# 245852  https://dam.malt.com/d2b7425b-8633-4c1c-8e3b-f...
# 245853  https://dam.malt.com/c7e64455-efbf-4ec7-ad3e-1...
# 245854                                   No profile image
#
#                                               headline   experience  price  \
# 0                        Consultant décisionnel Senior            -  700 €
# 1                         Aménagement de salle de bain            -  400 €
# 2                                 Photographe/Vidéaste            -  125 €
# 3                                          Webdesigner            -  499 €
# 4                                      Expert Java/JEE            -  550 €
# ...                                                ...          ...    ...
# 245850                            assistante virtuelle  15 ans et +  200 €
# 245851  Conseil Marketplaces | Mirakl Amazon Cdiscount      3-7 ans  300 €
# 245852                                      Traducteur      0-2 ans  125 €
# 245853                               Ingénieur système      3-7 ans  450 €
# 245854                 Montage video, flyers, affiches      0-2 ans    NaN
#
#        response_rate response_time                           categories  \
# 0               100%            1h                                   []
# 1                NaN            1h                                   []
# 2               100%            1h                      ['Photographe']
# 3               100%            1h                      ['Webdesigner']
# 4                50%            1h         ['Développeur Web Back-end']
# ...              ...           ...                                  ...
# 245850          100%            1h             ['Planneur Stratégique']
# 245851          100%            4h           ['Chef de projet digital']
# 245852          100%            1h  ['Community Manager', 'Traducteur']
# 245853          100%            1h      ['Designer Produit Industriel']
# 245854          100%            1h       ['Monteur vidéo', 'Graphiste']
#
#                                               competences supermalter  \
# 0       ['Business object', 'SQL Server', 'Microsoft B...         NaN
# 1       ['depannage', 'douche', 'bains', 'chauffage', ...         NaN
# 2       ['Photographie', 'Réalisation vidéo', 'paris',...         NaN
# 3                                              ['Design']         NaN
# 4       ['Hibernate', 'Spring', 'Eclipse', 'TDD', 'Scr...         NaN
# ...                                                   ...         ...
# 245850  ['Construction', 'Commerce de gros', 'Services...         NaN
# 245851  ['E-commerce', 'Commerce de détail', 'Marketpl...         NaN
# 245852  ['Traduction Français Anglais', 'Traduction An...         NaN
# 245853  ['Industrie électrique', 'Environnement et dév...         NaN
# 245854  ['Montage vidéo', 'Réseaux sociaux', 'Vidéo', ...         NaN
#
#                                                  location  \
# 0                                    {'Localisation': ''}
# 1                                    {'Localisation': ''}
# 2                                    {'Localisation': ''}
# 3                       {'Localisation': 'Paris, France'}
# 4                  {'Localisation': '89100 Sens, France'}
# ...                                                   ...
# 245850          {'Localisation': 'Choisy-le-Roi, France'}
# 245851                  {'Localisation': 'Lille, France'}
# 245852  {'Localisation': 'Collonges-sous-Salève, France'}
# 245853               {'Localisation': 'Poitiers, France'}
# 245854        {'Localisation': 'Bruxelles, VB, Belgique'}
#
#                                              presentation  recommendations  \
# 0       Consultant Senior en Business Intelligence , 1...              NaN
# 1       Bonjour je suis plombier-chauffagiste, spécial...              NaN
# 2                                                 Bonjour              NaN
# 3                                    Je vous dis bonjour.              NaN
# 4       Ancien Geek, soigné par 10 ans en Californie! ...              NaN
# ...                                                   ...              ...
# 245850  Je suis spécialisée dans l'assistance et le co...              NaN
# 245851  Le saviez-vous ?70% des ventes en ligne se fon...              NaN
# 245852  Hello !Je suis Tony et l’admin du groupe Plans...              NaN
# 245853  Fort de mes 5 années d'expérience dans le déve...              NaN
# 245854                                                NaN              NaN
#
#        missions  teletravail_preference                 profil  \
# 0           NaN                     NaN       alexandrelabayle
# 1           NaN                     NaN          josethermique
# 2           NaN                     NaN           jeremyherman
# 3           NaN                     NaN            vincehuguet
# 4           NaN                     NaN         patrickbernard
# ...         ...                     ...                    ...
# 245850      NaN                     NaN             lydiaronne
# 245851      NaN                     NaN        opheliedelville
# 245852      NaN                     NaN            tonymarando
# 245853      NaN                     NaN          matthieusager
# 245854      NaN                     NaN  divinemanuellamonongi
#
#                                                      link creation_date
# 0            https://www.malt.fr/profile/alexandrelabayle    2014-02-04
# 1               https://www.malt.fr/profile/josethermique    2014-02-19
# 2                https://www.malt.fr/profile/jeremyherman    2014-03-04
# 3                 https://www.malt.fr/profile/vincehuguet    2013-02-26
# 4              https://www.malt.fr/profile/patrickbernard    2013-10-26
# ...                                                   ...           ...
# 245850             https://www.malt.fr/profile/lydiaronne    2023-10-12
# 245851        https://www.malt.fr/profile/opheliedelville    2023-11-01
# 245852            https://www.malt.fr/profile/tonymarando    2023-10-26
# 245853          https://www.malt.fr/profile/matthieusager    2023-10-14
# 245854  https://www.malt.fr/profile/divinemanuellamonongi    2023-10-17
#
# [245855 rows x 18 columns]

# %%
# keep only link, creation_date and name

df_profile_links_not_scrapped = df_profile_links_not_scrapped[['creation_date', 'profil', 'link']]
df_profile_links_not_scrapped.to_csv('../../data/malt_profile_links_not_scrapped.csv', index=False)

df_profile_links_not_scrapped
# Out:
#        creation_date            profil  \
# 0         2014-01-08       bricetillet
# 2         2014-02-11  siobhanengelmann
# 6         2013-11-13    angeliqueurvoy
# 10        2014-01-03             emmag
# 14        2013-07-12       tommyjarnac
# ...              ...               ...
# 138794    2023-10-23         adamfisli
# 138796    2023-10-19  fredericforster1
# 138799    2023-10-29     gali203moutou
# 138800    2023-10-28           room309
# 138803    2023-11-04       eveguillard
#
#                                                 link
# 0            https://www.malt.fr/profile/bricetillet
# 2       https://www.malt.fr/profile/siobhanengelmann
# 6         https://www.malt.fr/profile/angeliqueurvoy
# 10                 https://www.malt.fr/profile/emmag
# 14           https://www.malt.fr/profile/tommyjarnac
# ...                                              ...
# 138794         https://www.malt.fr/profile/adamfisli
# 138796  https://www.malt.fr/profile/fredericforster1
# 138799     https://www.malt.fr/profile/gali203moutou
# 138800           https://www.malt.fr/profile/room309
# 138803       https://www.malt.fr/profile/eveguillard
#
# [86125 rows x 3 columns]
