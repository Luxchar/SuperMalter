# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../../datasets/raw_malt_data.csv')
df
# Out:
# /tmp/ipykernel_6307/1382496996.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../datasets/malt_data.csv')
#                name                                      profile_image  \
# 0               NaN                                   No profile image
# 1        Mickael M.  https://dam.malt.com/ecrimpl92gqieb0ijvjo?grav...
# 2               NaN                                                NaN
# 3      Nacera  TIZI  https://dam.malt.com/erokb7omnnhmf79bojnr?grav...
# 4       Aurélien D.  https://dam.malt.com/vabndz3c9dkhsimtvgww?grav...
# ...             ...                                                ...
# 61987           NaN                                                NaN
# 61988           NaN                                   No profile image
# 61989    Clément L.  https://dam.malt.com/orcofeyxlvym8yfp8lpb?grav...
# 61990           NaN                                   No profile image
# 61991           NaN                                                NaN
#
#                                        headline experience  price  \
# 0                                           NaN        NaN    NaN
# 1                                     Graphiste          -  250 €
# 2                                           NaN        NaN    NaN
# 3                         Commerciale Freelance          -   40 €
# 4             SysOps, DevOps et développeur web   8-15 ans  550 €
# ...                                         ...        ...    ...
# 61987                                       NaN        NaN    NaN
# 61988                                       NaN        NaN    NaN
# 61989  recherche freelance sous yii framework !   8-15 ans  480 €
# 61990                                       NaN        NaN    NaN
# 61991                                       NaN        NaN    NaN
#
#       response_rate   response_time  \
# 0               NaN             NaN
# 1              100%  Quelques jours
# 2               NaN             NaN
# 3               NaN              1h
# 4              100%              1h
# ...             ...             ...
# 61987           NaN             NaN
# 61988           NaN             NaN
# 61989          100%  Quelques jours
# 61990           NaN             NaN
# 61991           NaN             NaN
#
#                                               categories  \
# 0                                                     []
# 1                                          ['Graphiste']
# 2                                                    NaN
# 3                                ['Business developers']
# 4      ['Administrateur base de données', 'Administra...
# ...                                                  ...
# 61987                                                NaN
# 61988                                                 []
# 61989  ['Développeur CMS', 'Développeur Web Back-end'...
# 61990                                                 []
# 61991                                                NaN
#
#                                              competences supermalter  \
# 0                                                     []         NaN
# 1      ['Wordpress', 'Design logo', 'Affiche', 'Carte...         NaN
# 2                                                    NaN         NaN
# 3                            ['Tanger et tout le Maroc']         NaN
# 4      ['Linux', 'Ansible', 'PHP', 'Apache', 'Proxmox...         NaN
# ...                                                  ...         ...
# 61987                                                NaN         NaN
# 61988                                                 []         NaN
# 61989  ['Développement Back-End', 'Yii', 'Développeme...         NaN
# 61990                                                 []         NaN
# 61991                                                NaN         NaN
#
#                                                 location  \
# 0                                                    NaN
# 1                {'Localisation': '21000 Dijon, France'}
# 2                                                    NaN
# 3      {'Localisation': 'Tanger, Tanger-Tétouan, Maroc'}
# 4                {'Localisation': 'La Rochelle, France'}
# ...                                                  ...
# 61987                                                NaN
# 61988                                                NaN
# 61989              {'Localisation': 'Bressuire, France'}
# 61990                                                NaN
# 61991                                                NaN
#
#                                             presentation  recommendations  \
# 0                                                    NaN              NaN
# 1      Passionné depuis mon enfance par le graphisme,...              NaN
# 2                                                    NaN              NaN
# 3      Parce que La ville de Tanger tend à devenir l'...              NaN
# 4      SysOps (unix) depuis 5 ans et DevOps depuis 4 ...              1.0
# ...                                                  ...              ...
# 61987                                                NaN              NaN
# 61988                                                NaN              NaN
# 61989  Hello,développeur web depuis 11 ans (encore pl...              NaN
# 61990                                                NaN              NaN
# 61991                                                NaN              NaN
#
#       missions  teletravail_preference            profil  \
# 0          NaN                     NaN       bricetillet
# 1          NaN                     NaN     mickaelmolina
# 2          NaN                     NaN  alexandrelabayle
# 3          NaN                     NaN        naceratizi
# 4           12                     NaN      aureliendazy
# ...        ...                     ...               ...
# 61987      NaN                     NaN      kelvinguezou
# 61988      NaN                     NaN    cindymontanger
# 61989      NaN                     NaN    clementlambert
# 61990      NaN                     NaN  stephaniebernard
# 61991      NaN                     NaN  gwendolinepresle
#
#                                                link creation_date
# 0           https://www.malt.fr/profile/bricetillet    2014-01-08
# 1         https://www.malt.fr/profile/mickaelmolina    2013-08-02
# 2      https://www.malt.fr/profile/alexandrelabayle    2014-02-04
# 3            https://www.malt.fr/profile/naceratizi    2014-02-22
# 4          https://www.malt.fr/profile/aureliendazy    2013-06-06
# ...                                             ...           ...
# 61987      https://www.malt.fr/profile/kelvinguezou    2018-12-03
# 61988    https://www.malt.fr/profile/cindymontanger    2018-11-23
# 61989    https://www.malt.fr/profile/clementlambert    2018-11-29
# 61990  https://www.malt.fr/profile/stephaniebernard    2018-11-22
# 61991  https://www.malt.fr/profile/gwendolinepresle    2018-12-03
#
# [61992 rows x 18 columns]

# %%
# separate the data into two dataframes

# if the name is NaN, then the data is not scrapped
df_data_scrapped = df[df['name'].notna()]
df_profile_links_not_scrapped = df[df['name'].isna()]

df_data_scrapped.to_csv('../../datasets/malt_data_scrapped.csv', index=False)
df_data_scrapped
# Out:
#                     name                                      profile_image  \
# 1             Mickael M.  https://dam.malt.com/ecrimpl92gqieb0ijvjo?grav...
# 3           Nacera  TIZI  https://dam.malt.com/erokb7omnnhmf79bojnr?grav...
# 4            Aurélien D.  https://dam.malt.com/vabndz3c9dkhsimtvgww?grav...
# 5         Youri Galescot  https://dam.malt.com/r3nb6gaf6723bi1unhhx?grav...
# 7         Julien Trezeux  https://dam.malt.com/pllhwpaapz84yfqmc7rw?grav...
# ...                  ...                                                ...
# 61981  Andressa Molinari  https://dam.malt.com/iy7gl5dx2nnugo8a1pam?grav...
# 61982    Romain Gaillard  https://dam.malt.com/jsgd3vbmfu3bfjev4cbz?grav...
# 61984      Joanna Martyn  https://dam.malt.com/fvoe0gnvnvs4rdflao5i?grav...
# 61985     Jade Teychenné  https://dam.malt.com/p6asbtfqvil81rrlahkx?grav...
# 61989         Clément L.  https://dam.malt.com/orcofeyxlvym8yfp8lpb?grav...
#
#                                               headline experience  price  \
# 1                                            Graphiste          -  250 €
# 3                                Commerciale Freelance          -   40 €
# 4                    SysOps, DevOps et développeur web   8-15 ans  550 €
# 5                  Développeur web frontend et backend          -  235 €
# 7      directeur artistique - graphiste - illustrateur   8-15 ans  350 €
# ...                                                ...        ...    ...
# 61981                   Traductrice français/portugais    0-2 ans  130 €
# 61982               directeur artistique | ui designer    3-7 ans  350 €
# 61984            Fashion stylist, Social media manager    0-2 ans  150 €
# 61985                           Traducteur - Rédacteur    0-2 ans  125 €
# 61989         recherche freelance sous yii framework !   8-15 ans  480 €
#
#       response_rate   response_time  \
# 1              100%  Quelques jours
# 3               NaN              1h
# 4              100%              1h
# 5               33%             12h
# 7              100%              1h
# ...             ...             ...
# 61981           NaN              1h
# 61982          100%             24h
# 61984          100%              1h
# 61985          100%              1h
# 61989          100%  Quelques jours
#
#                                               categories  \
# 1                                          ['Graphiste']
# 3                                ['Business developers']
# 4      ['Administrateur base de données', 'Administra...
# 5                                                     []
# 7           ['Photographe', 'Graphiste', 'Illustrateur']
# ...                                                  ...
# 61981                                     ['Traducteur']
# 61982  ['Directeur artistique', 'UI Designer', 'UX De...
# 61984  ['Community Manager', 'Photographe', 'Directeu...
# 61985  ['Concepteur Rédacteur', 'Pigiste', 'Rédacteur...
# 61989  ['Développeur CMS', 'Développeur Web Back-end'...
#
#                                              competences supermalter  \
# 1      ['Wordpress', 'Design logo', 'Affiche', 'Carte...         NaN
# 3                            ['Tanger et tout le Maroc']         NaN
# 4      ['Linux', 'Ansible', 'PHP', 'Apache', 'Proxmox...         NaN
# 5      ['PHP', 'HTML5', 'CSS3', 'SEO', 'jQuery', 'Res...         NaN
# 7      ['Direction artistique', 'Graphisme', 'Design ...         NaN
# ...                                                  ...         ...
# 61981  ['Traduction Français Portugais', 'brésilienne...         NaN
# 61982  ['User Interface Design', 'User Experience Des...         NaN
# 61984  ['Photographie', 'Adobe Photoshop', 'Retouche ...         NaN
# 61985  ['Traduction Français Anglais', 'Rédaction web...         NaN
# 61989  ['Développement Back-End', 'Yii', 'Développeme...         NaN
#
#                                                 location  \
# 1                {'Localisation': '21000 Dijon, France'}
# 3      {'Localisation': 'Tanger, Tanger-Tétouan, Maroc'}
# 4                {'Localisation': 'La Rochelle, France'}
# 5                      {'Localisation': 'Paris, France'}
# 7      {'Localisation': 'Paris, France / www.graphicf...
# ...                                                  ...
# 61981                  {'Localisation': 'Lille, France'}
# 61982                  {'Localisation': 'Paris, France'}
# 61984                  {'Localisation': 'Paris, France'}
# 61985                  {'Localisation': 'Paris, France'}
# 61989              {'Localisation': 'Bressuire, France'}
#
#                                             presentation  recommendations  \
# 1      Passionné depuis mon enfance par le graphisme,...              NaN
# 3      Parce que La ville de Tanger tend à devenir l'...              NaN
# 4      SysOps (unix) depuis 5 ans et DevOps depuis 4 ...              1.0
# 5      Bonjour,Je suis développeur frontend et backen...              NaN
# 7      Graphiste et directeur artistique depuis 2007,...              3.0
# ...                                                  ...              ...
# 61981  Brésilienne passionnée par la France je vous o...              NaN
# 61982  Bonjour,Avec 5 années d’expériences dans le de...              NaN
# 61984  Ambitieuse, travailleuse, créative avec une co...              NaN
# 61985                                                NaN              NaN
# 61989  Hello,développeur web depuis 11 ans (encore pl...              NaN
#
#       missions  teletravail_preference            profil  \
# 1          NaN                     NaN     mickaelmolina
# 3          NaN                     NaN        naceratizi
# 4           12                     NaN      aureliendazy
# 5          NaN                     NaN     yourigalescot
# 7          NaN                     NaN     julientrezeux
# ...        ...                     ...               ...
# 61981      NaN                     NaN  andressamolinari
# 61982      NaN                     NaN   romaingaillard1
# 61984      NaN                     NaN      joannamartyn
# 61985      NaN                     NaN     jadeteychenne
# 61989      NaN                     NaN    clementlambert
#
#                                                link creation_date
# 1         https://www.malt.fr/profile/mickaelmolina    2013-08-02
# 3            https://www.malt.fr/profile/naceratizi    2014-02-22
# 4          https://www.malt.fr/profile/aureliendazy    2013-06-06
# 5         https://www.malt.fr/profile/yourigalescot    2014-02-18
# 7         https://www.malt.fr/profile/julientrezeux    2014-02-12
# ...                                             ...           ...
# 61981  https://www.malt.fr/profile/andressamolinari    2018-11-27
# 61982   https://www.malt.fr/profile/romaingaillard1    2018-11-23
# 61984      https://www.malt.fr/profile/joannamartyn    2018-11-30
# 61985     https://www.malt.fr/profile/jadeteychenne    2018-11-21
# 61989    https://www.malt.fr/profile/clementlambert    2018-11-29
#
# [33760 rows x 18 columns]

# %%
# keep only link, creation_date and name

df_profile_links_not_scrapped = df_profile_links_not_scrapped[['link', 'creation_date', 'name']]
df_profile_links_not_scrapped.to_csv('../../datasets/malt_profile_links_not_scrapped.csv', index=False)

df_profile_links_not_scrapped
# Out:
#                                                link creation_date name
# 0           https://www.malt.fr/profile/bricetillet    2014-01-08  NaN
# 2      https://www.malt.fr/profile/alexandrelabayle    2014-02-04  NaN
# 6      https://www.malt.fr/profile/siobhanengelmann    2014-02-11  NaN
# 9         https://www.malt.fr/profile/josethermique    2014-02-19  NaN
# 10         https://www.malt.fr/profile/jeremyherman    2014-03-04  NaN
# ...                                             ...           ...  ...
# 61986        https://www.malt.fr/profile/rubenfessu    2018-12-01  NaN
# 61987      https://www.malt.fr/profile/kelvinguezou    2018-12-03  NaN
# 61988    https://www.malt.fr/profile/cindymontanger    2018-11-23  NaN
# 61990  https://www.malt.fr/profile/stephaniebernard    2018-11-22  NaN
# 61991  https://www.malt.fr/profile/gwendolinepresle    2018-12-03  NaN
#
# [28232 rows x 3 columns]
