# %% [markdown]
# # Learning model data(TJM)
#
# * Experience
# * Region
# * Category
# * SuperMalter
# * price

# %% [markdown]
# # Final cleanup of the csv file for our LM

# %%
import pandas as pd
import ast


# import the data
df_cities = pd.read_csv('../scrapping/datasets/cities_list.csv')
df_malt = pd.read_csv('../scrapping/datasets/malt_sample_data.csv')

# Convert the string 'location' column to a dictionary and extract the city
def extract_city(location_str):
    try:
        location_dict = ast.literal_eval(location_str)
        city_country = location_dict.get('Localisation', '')
        city = city_country.split(',')[0].strip()
        return city
    except:
        return None

df_malt['Ville'] = df_malt['location'].apply(extract_city)

# Exact match to find the area
def find_region_name(city):
    for index, row in df_cities.iterrows():
        if city.lower() == row['label'].lower():
            return row['region_name']
    return None

df_malt['Region_Name'] = df_malt['Ville'].apply(find_region_name)

# Remove lines where 'Region_Name' is missing
df_malt.dropna(subset=['Region_Name'], inplace=True)


# Removing unnecessary columns
columns_to_drop = ['name', 'location', 'presentation', 'recommendations', 
                   'teletravail_preference',  'Ville', 'competences', 'response_time',
                     'response_rate', 'headline', 'missions']
df_malt = df_malt.drop(columns=columns_to_drop)

# Cleaning up the 'price' column
df_malt['price'] = df_malt['price'].str.replace('€', '').str.replace('\u202f', '').str.replace(r'\D', '', regex=True).astype(int)

# Replace the values in the 'supermalter' column
df_malt['supermalter'] = df_malt['supermalter'].apply(lambda x: 1 if x == 'Supermalter' else 0)


df_malt.to_csv('../datasets/ml_sample_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aboub\Desktop\ScrapMalt\ML Missions\Parsing.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>             return row['region_name']
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a>     return None
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a> df_malt['Region_Name'] = df_malt['Ville'].apply(find_region_name)
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> # Remove lines where 'Region_Name' is missing
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> df_malt.dropna(subset=['Region_Name'], inplace=True)
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# c:\Users\aboub\Desktop\ScrapMalt\ML Missions\Parsing.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> def find_region_name(city):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=22'>23</a>     for index, row in df_cities.iterrows():
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a>         if city.lower() == row['label'].lower():
#      <a href='vscode-notebook-cell:/c%3A/Users/aboub/Desktop/ScrapMalt/ML%20Missions/Parsing.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>             return row['region_name']
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\frame.py:1450, in DataFrame.iterrows(self)
#    1448 using_cow = using_copy_on_write()
#    1449 for k, v in zip(self.index, self.values):
# -> 1450     s = klass(v, index=columns, name=k).__finalize__(self)
#    1451     if using_cow and self._mgr.is_single_block:
#    1452         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\generic.py:6169, in NDFrame.__finalize__(self, other, method, **kwargs)
#    6166 for name in other.attrs:
#    6167     self.attrs[name] = other.attrs[name]
# -> 6169 self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    6170 # For subclasses using _metadata.
#    6171 for name in set(self._metadata) & set(other._metadata):
#
# File c:\Users\aboub\anaconda3\envs\pydel\Lib\site-packages\pandas\core\flags.py:91, in Flags.allows_duplicate_labels(self, value)
#      89 @allows_duplicate_labels.setter
#      90 def allows_duplicate_labels(self, value: bool) -> None:
# ---> 91     value = bool(value)
#      92     obj = self._obj()
#      93     if obj is None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualisation

# %%
import pandas as pd

df_cities = pd.read_csv('../scrapping/data/Clean.csv')
df_cities
# Out:
#      price   experience missions  \
# 0      250     8-15 ans    1 158
# 1      400  15 ans et +      351
# 2      260     8-15 ans    1 085
# 3      250      3-7 ans      265
# 4      260      3-7 ans      148
# ..     ...          ...      ...
# 184    450  15 ans et +      133
# 185    200     8-15 ans      139
# 186    350      3-7 ans       11
# 187    400     8-15 ans      114
# 188    550     8-15 ans       17
#
#                                             categories  supermalter  \
# 0                      ['Rédacteur web', 'Traducteur']            1
# 1    ['Développeur CMS', 'Développeur Web Front-end...            1
# 2    ['Concepteur Rédacteur', 'Pigiste', 'Rédacteur...            1
# 3    ['Concepteur Rédacteur', 'Pigiste', 'Rédacteur...            1
# 4                 ['Monteur vidéo', 'Motion Designer']            0
# ..                                                 ...          ...
# 184  ['Directeur artistique', 'Graphiste', 'Illustr...            1
# 185                                       ['Voix off']            1
# 186  ['Développeur CMS', 'Développeur Web Front-end...            0
# 187  ['Monteur vidéo', 'Photographe', 'Réalisateur ...            1
# 188  ['Motion Designer', 'Réalisateur vidéo', 'Voix...            1
#
#        Region_Name
# 0    île-de-france
# 1    île-de-france
# 2    île-de-france
# 3    île-de-france
# 4    île-de-france
# ..             ...
# 184  île-de-france
# 185  île-de-france
# 186  île-de-france
# 187  île-de-france
# 188  île-de-france
#
# [189 rows x 6 columns]
