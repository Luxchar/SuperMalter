# %%
# import modules
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

df = pd.read_csv('../../datasets/parsed_malt_data.csv')
df
# Out:
#                     name                                      profile_image  \
# 0             Mickael M.  https://dam.malt.com/ecrimpl92gqieb0ijvjo?grav...
# 1           Nacera  TIZI  https://dam.malt.com/erokb7omnnhmf79bojnr?grav...
# 2            Aurélien D.  https://dam.malt.com/vabndz3c9dkhsimtvgww?grav...
# 3         Youri Galescot  https://dam.malt.com/r3nb6gaf6723bi1unhhx?grav...
# 4         Julien Trezeux  https://dam.malt.com/pllhwpaapz84yfqmc7rw?grav...
# ...                  ...                                                ...
# 33755  Andressa Molinari  https://dam.malt.com/iy7gl5dx2nnugo8a1pam?grav...
# 33756    Romain Gaillard  https://dam.malt.com/jsgd3vbmfu3bfjev4cbz?grav...
# 33757      Joanna Martyn  https://dam.malt.com/fvoe0gnvnvs4rdflao5i?grav...
# 33758     Jade Teychenné  https://dam.malt.com/p6asbtfqvil81rrlahkx?grav...
# 33759         Clément L.  https://dam.malt.com/orcofeyxlvym8yfp8lpb?grav...
#
#                                               headline experience  price  \
# 0                                            Graphiste          -    250
# 1                                Commerciale Freelance          -     40
# 2                    SysOps, DevOps et développeur web   8-15 ans    550
# 3                  Développeur web frontend et backend          -    235
# 4      directeur artistique - graphiste - illustrateur   8-15 ans    350
# ...                                                ...        ...    ...
# 33755                   Traductrice français/portugais    0-2 ans    130
# 33756               directeur artistique | ui designer    3-7 ans    350
# 33757            Fashion stylist, Social media manager    0-2 ans    150
# 33758                           Traducteur - Rédacteur    0-2 ans    125
# 33759         recherche freelance sous yii framework !   8-15 ans    480
#
#        response_rate   response_time  \
# 0               1.00  Quelques jours
# 1                NaN              1h
# 2               1.00              1h
# 3               0.33             12h
# 4               1.00              1h
# ...              ...             ...
# 33755            NaN              1h
# 33756           1.00             24h
# 33757           1.00              1h
# 33758           1.00              1h
# 33759           1.00  Quelques jours
#
#                                               categories  \
# 0                                          ['Graphiste']
# 1                                ['Business developers']
# 2      ['Administrateur base de données', 'Administra...
# 3                                                     []
# 4           ['Photographe', 'Graphiste', 'Illustrateur']
# ...                                                  ...
# 33755                                     ['Traducteur']
# 33756  ['Directeur artistique', 'UI Designer', 'UX De...
# 33757  ['Community Manager', 'Photographe', 'Directeu...
# 33758  ['Concepteur Rédacteur', 'Pigiste', 'Rédacteur...
# 33759  ['Développeur CMS', 'Développeur Web Back-end'...
#
#                                                   skills  supermalter  \
# 0      ['Wordpress', 'Design logo', 'Affiche', 'Carte...            0
# 1                            ['Tanger et tout le Maroc']            0
# 2      ['Linux', 'Ansible', 'PHP', 'Apache', 'Proxmox...            0
# 3      ['PHP', 'HTML5', 'CSS3', 'SEO', 'jQuery', 'Res...            0
# 4      ['Direction artistique', 'Graphisme', 'Design ...            0
# ...                                                  ...          ...
# 33755  ['Traduction Français Portugais', 'brésilienne...            0
# 33756  ['User Interface Design', 'User Experience Des...            0
# 33757  ['Photographie', 'Adobe Photoshop', 'Retouche ...            0
# 33758  ['Traduction Français Anglais', 'Rédaction web...            0
# 33759  ['Développement Back-End', 'Yii', 'Développeme...            0
#
#                                                 location  \
# 0                {'Localisation': '21000 Dijon, France'}
# 1      {'Localisation': 'Tanger, Tanger-Tétouan, Maroc'}
# 2                {'Localisation': 'La Rochelle, France'}
# 3                      {'Localisation': 'Paris, France'}
# 4      {'Localisation': 'Paris, France / www.graphicf...
# ...                                                  ...
# 33755                  {'Localisation': 'Lille, France'}
# 33756                  {'Localisation': 'Paris, France'}
# 33757                  {'Localisation': 'Paris, France'}
# 33758                  {'Localisation': 'Paris, France'}
# 33759              {'Localisation': 'Bressuire, France'}
#
#                                             presentation  recommendations  \
# 0      Passionné depuis mon enfance par le graphisme,...                0
# 1      Parce que La ville de Tanger tend à devenir l'...                0
# 2      SysOps (unix) depuis 5 ans et DevOps depuis 4 ...                1
# 3      Bonjour,Je suis développeur frontend et backen...                0
# 4      Graphiste et directeur artistique depuis 2007,...                3
# ...                                                  ...              ...
# 33755  Brésilienne passionnée par la France je vous o...                0
# 33756  Bonjour,Avec 5 années d’expériences dans le de...                0
# 33757  Ambitieuse, travailleuse, créative avec une co...                0
# 33758                                                NaN                0
# 33759  Hello,développeur web depuis 11 ans (encore pl...                0
#
#        missions  teletravail_preference            profil  \
# 0             0                       0     mickaelmolina
# 1             0                       0        naceratizi
# 2            12                       0      aureliendazy
# 3             0                       0     yourigalescot
# 4             0                       0     julientrezeux
# ...         ...                     ...               ...
# 33755         0                       0  andressamolinari
# 33756         0                       0   romaingaillard1
# 33757         0                       0      joannamartyn
# 33758         0                       0     jadeteychenne
# 33759         0                       0    clementlambert
#
#                                                link creation_date
# 0         https://www.malt.fr/profile/mickaelmolina    2013-08-02
# 1            https://www.malt.fr/profile/naceratizi    2014-02-22
# 2          https://www.malt.fr/profile/aureliendazy    2013-06-06
# 3         https://www.malt.fr/profile/yourigalescot    2014-02-18
# 4         https://www.malt.fr/profile/julientrezeux    2014-02-12
# ...                                             ...           ...
# 33755  https://www.malt.fr/profile/andressamolinari    2018-11-27
# 33756   https://www.malt.fr/profile/romaingaillard1    2018-11-23
# 33757      https://www.malt.fr/profile/joannamartyn    2018-11-30
# 33758     https://www.malt.fr/profile/jadeteychenne    2018-11-21
# 33759    https://www.malt.fr/profile/clementlambert    2018-11-29
#
# [33760 rows x 18 columns]

# %% [markdown]
# ### HOW MUCH DOES EXPERIENCE MATTER?

# %% [markdown]
# How experienced are freelancers ?

# %%
df['creation_date'] = pd.to_datetime(df['creation_date'], format='%Y-%m-%d')

# remove rows with no experience
df = df[df['experience'] != '-']

# Compter le nombre d'occurrences pour chaque année
occurrences = df['experience'].value_counts()

# sort data by year
occurrences = occurrences.sort_index()

# put a specific order
occurrences = occurrences.reindex(['0-2 ans', '3-7 ans', '8-15 ans', '15 ans et +'])

# bar plot
occurrences.plot(kind='bar')

# plot the data
plt.show()

# %% [markdown]
# Average and Median TJM for every experience level

# %% [markdown]
# Replot with mission cleaning: remove outliers that haven't done at least the equivalent of 1 mission per year on the platform

# %% [markdown]
# number of supermalter per experience level (are there more supermalter in the most experienced freelancers ?)

# %% [markdown]
# ### CATEGORIES OF FREELANCERS

# %% [markdown]
# TOP 5 categories that get the best salary: is there a best category to be in (salary, length of mission?)

# %% [markdown]
# BEST 5 SKILLS to get in these top 5 categories

# %% [markdown]
# ### REMOTE WORK: DOES IT PAY OFF?

# %% [markdown]
# compare tjm for remote work vs on site work

# %% [markdown]
# compare how much missions are remote vs on site (how big is the market for remote work ?)

# %% [markdown]
# compare experience level of remote workers vs non remote workers

# %% [markdown]
# ### RECOMMANDATIONS

# %% [markdown]
# Do successful freelancers have recommandations ? (need ideas to develop this part)
